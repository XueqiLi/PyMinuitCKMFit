# %%
import os
import sys
from matplotlib import pyplot as plt
nb_dir = os.path.split(os.getcwd())[0]

# %%
# %run fit modelExample
# Out:
# scan done, current chi-sqr= 219003.11213451633
# simplex done, current chi-sqr= 5282.893891162332
# migrad done 2000 times, current chi-sqr: 306.9268591220093
# migrad done 4000 times, current chi-sqr: 306.92685877969825
# migrad done 6000 times, current chi-sqr: 306.9268587791987
# migrad done 8000 times, current chi-sqr: 306.92685877919064
# migrad done 10000 times, current chi-sqr: 306.92685877919064
# migrad done 12000 times, current chi-sqr: 306.92685877919064
# migrad done 14000 times, current chi-sqr: 306.92685877919064
# migrad done 16000 times, current chi-sqr: 306.92685877919064
# migrad done 18000 times, current chi-sqr: 306.92685877919064
# migrad done 20000 times, current chi-sqr: 306.92685877919064
# ==========================================================
#
#
# Fit Result
# [-1.8503761  -0.00260821 -0.47681055  0.87809178]
#
#
# Observabls Result:
# s12 :  0.4908982734852185
# s23 :  0.6415259380170464
# s13 :  0.02205089156059242
# m21Rm31 :  0.02989829763550026
# mERmMu :  0.004799994577155787
# mMuRMTau :  0.059493202807288356
#
#
# Sigma Away:
# s12 :  291.78315023740464
# s23 :  14.919308818364762
# s13 :  0.0013917643622024384
# m21Rm31 :  0.16219570604459704
# mERmMu :  7.351809838910202e-10
# mMuRMTau :  0.06081225227927962
#
#
# total chi-sqr:  306.92685877919064

# %%
commonBounds = (-5,5)
tBounds = [
    (-0.3,0.3),        # tr
    (1,1.3)   #ti
]

parameterBoundsWithoutT = [commonBounds for i in range(numberOfParams)]
parameterBounds = parameterBoundsWithoutT + tBounds

initParams = [np.random.uniform(low=bound[0], high=bound[1]) for bound in parameterBounds]
fit = Minuit(costFunction, initParams) 
fit.limits=parameterBounds

# %%
fit.scan(70000)
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                 Scan                                    │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 2.536e+04                  │             Nfcn = 65551             │
# │ EDM = 1.38e+04 (Goal: 0.1)       │           time = 25.1 sec            │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │         INVALID Minimum          │   ABOVE EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Hesse not run           │            NO covariance             │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ x0   │  1.6667   │  0.0005   │            │            │   -5    │    5    │       │
# │ 1 │ x1   │  -1.000   │   0.004   │            │            │   -5    │    5    │       │
# │ 2 │ x2   │  -0.020   │   0.002   │            │            │  -0.3   │   0.3   │       │
# │ 3 │ x3   │  1.2800   │  0.0008   │            │            │    1    │   1.3   │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %%
fit.simplex()
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                               Simplex                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 347.6                      │             Nfcn = 65886             │
# │ EDM = 103 (Goal: 0.1)            │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │         INVALID Minimum          │   ABOVE EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Hesse not run           │            NO covariance             │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ x0   │  1.73415  │  0.00030  │            │            │   -5    │    5    │       │
# │ 1 │ x1   │  -0.308   │   0.007   │            │            │   -5    │    5    │       │
# │ 2 │ x2   │  -0.1238  │  0.0016   │            │            │  -0.3   │   0.3   │       │
# │ 3 │ x3   │  1.1682   │  0.0014   │            │            │    1    │   1.3   │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %%
fit.migrad(200000,20000)
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 19.03                      │             Nfcn = 66017             │
# │ EDM = 1.63e-07 (Goal: 0.0002)    │           time = 25.0 sec            │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ x0   │  1.73366  │  0.00009  │            │            │   -5    │    5    │       │
# │ 1 │ x1   │  -0.272   │   0.009   │            │            │   -5    │    5    │       │
# │ 2 │ x2   │  -0.1928  │  0.0029   │            │            │  -0.3   │   0.3   │       │
# │ 3 │ x3   │   1.085   │   0.004   │            │            │    1    │   1.3   │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌────┬─────────────────────────────────────┐
# │    │       x0       x1       x2       x3 │
# ├────┼─────────────────────────────────────┤
# │ x0 │  7.7e-09  -500e-9    36e-9    56e-9 │
# │ x1 │  -500e-9 8.51e-05     1e-6 0.001e-3 │
# │ x2 │    36e-9     1e-6 8.25e-06     9e-6 │
# │ x3 │    56e-9 0.001e-3     9e-6 1.46e-05 │
# └────┴─────────────────────────────────────┘

# %%
np.asarray(fit.values)
# Out:
# array([ 1.73365932, -0.27152867, -0.19283536,  1.08470929])

# %%
for i in range(10):
    initParams = [np.random.uniform(low=bound[0], high=bound[1]) for bound in parameterBounds]
    fit.values = initParams
    fit.scan(10000)
    fit.simplex()
    fit.migrad()
    print(fit.values,"\n",costFunction(np.asarray(fit.values)))
# Out:
# <ValueView x0=1.7336591640642123 x1=0.2715243517559154 x2=-0.19283680658717933 x3=1.0847029349067052>
#  19.03294928099922
# <ValueView x0=1.7336593400271658 x1=0.27153017586674455 x2=-0.19283461587999162 x3=1.0847098551246228>
#  19.032941923998557
# <ValueView x0=1.7304425049078436 x1=0.2712162620110803 x2=-0.1926731795495631 x3=1.0848585667261372>
#  18.791535901818847
# <ValueView x0=1.7304429309615674 x1=0.27120196283607 x2=-0.19267141279926747 x3=1.0848874823118824>
#  18.791353181165444
# <ValueView x0=1.7336593517979075 x1=0.271529348462094 x2=0.19283293146072694 x3=1.0847087459693698>
#  19.03294373684061
# <ValueView x0=1.7336593066366923 x1=0.27153911555287813 x2=0.19283672868392027 x3=1.0847104561010488>
#  19.032946664628113
# <ValueView x0=1.733659248940759 x1=0.2715476545322302 x2=-0.19283556053063095 x3=1.0847023921677246>
#  19.03295872872132
# <ValueView x0=1.7336592822206374 x1=0.2715318519319858 x2=0.19283374491671595 x3=1.084709439881914>
#  19.032943064396456
# <ValueView x0=1.730442834221689 x1=0.2712099887061461 x2=-0.19266432207700812 x3=1.0848938496262133>
#  18.791355286573744
# <ValueView x0=1.7336595823232992 x1=0.2714874573309647 x2=-0.19284928178451127 x3=1.0847026144011889>
#  19.033070205183062
